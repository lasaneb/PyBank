# %%
import pandas as pd
from pathlib import Path
import csv

# %%
# file path set

filepath = Path("/Users/xbook/Desktop/Bootcamp/FinTech/Miami-Homework/python-homework/PyBank/budget_data.csv")

# %%
# print(filepath)

# %%
with open(filepath, "r") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
    csv_header = next(csvreader)
# print(csv_header)
    total = 0
    profit = 0
    for row in csvreader:
        # profit = (row[1])
        total += int(row[1])
        # print(profit)
        print (total)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/70/t086ych1523c8x6dtlxcngr80000gn/T/ipykernel_4843/2302493117.py in <module>
# ----> 1 with open(filepath, "r") as csvfile:
#       2     csvreader = csv.reader(csvfile, delimiter=",")
#       3     csv_header = next(csvreader)
#       4 # print(csv_header)
#       5     total = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/xbook/Desktop/Bootcamp/FinTech/Miami-Homework/python-homework/PyBank/budget_data.csv'
